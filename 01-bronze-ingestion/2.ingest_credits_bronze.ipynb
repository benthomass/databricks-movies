# %%
# %run ../setup/config

# %%
# %run ../setup/utils

# %%
credits_schema = StructType([
    StructField("cast", StringType(), True),
    StructField("crew", StringType(), True),
    StructField("id", IntegerType(), True),
])
source_csv = f"{raw_folder_path}/credits.csv"
target_delta = f"{bronze_folder_path}/credits"
credits_df = ingest_to_bronze(spark, credits_schema, source_csv, target_delta)
display(credits_df)
