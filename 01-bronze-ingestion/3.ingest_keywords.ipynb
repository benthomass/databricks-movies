# %%
# %run ../setup/config

# %%
# %run ../setup/utils

# %%
keywords_schema = StructType([
        StructField("id", StringType(), True),
        StructField("keywords", StringType(), True)
    ])
source_csv = f"{raw_folder_path}/keywords.csv"
target_delta = f"{bronze_folder_path}/keywords"
keywords_df = ingest_to_bronze(spark, keywords_schema, source_csv, target_delta)
display(keywords_df)
