# %%
# %run ../setup/config

# %%
# %run ../setup/utils

# %%
links_small_schema = StructType(
    [
        StructField("movieId", IntegerType(), True),
        StructField("imdbId", IntegerType(), True),
        StructField("tmdbId", IntegerType(), True),
    ]
)
source_csv = f"{raw_folder_path}/links_small.csv"
target_delta = f"{bronze_folder_path}/links_small"
links_small_df = ingest_to_bronze(spark, links_small_schema, source_csv, target_delta)
display(links_small_df.limit(5))
