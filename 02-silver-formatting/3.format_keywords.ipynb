# %%
# %run ../setup/config

# %%
# %run ../setup/utils

# %%
keywords_df = spark.read.format("delta").load(f"{bronze_folder_path}/keywords")

# %%
keywords_schema = StructType([
  StructField("id", IntegerType(), True),
  StructField("name", StringType(), True),
])

# %%
keywords_df = explode_nested_json_array_silver(
    keywords_df, "keywords", "id", keywords_schema, ["id", "name"]
)

# %%
keywords_df.write.mode("overwrite").format("delta").save(f"{silver_folder_path}/keywords")
