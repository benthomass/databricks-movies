# %%
# %run ../setup/config

# %%
# %run ../setup/utils

# %%
links_df = spark.read.format("delta").load(f"{bronze_folder_path}/links")
ratings_df = spark.read.format("delta").load(f"{bronze_folder_path}/ratings")

# %%
links_df.write.format("delta").mode("overwrite").save(f"{silver_folder_path}/links")
ratings_df.write.format("delta").mode("overwrite").save(f"{silver_folder_path}/ratings")
